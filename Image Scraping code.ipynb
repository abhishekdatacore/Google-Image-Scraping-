# %%
import  requests
from bs4 import BeautifulSoup
from urllib.request import urlopen as uReq
import logging 
import os

# %%
save_dir = "images/"
if not os.path.exists(save_dir):
    os.makedirs(save_dir)

# %%
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36"
}

# %%
query = "Captain America"
response = requests.get(f"https://www.google.com/search?q={query}+images&sca_esv=8246e02b3da205e5&udm=2&biw=1507&bih=679&aic=0&ei=tJxeaarTLcziseMP0Y_BgQg&oq=captain+america+im&gs_lp=Egtnd3Mtd2l6LWltZyISY2FwdGFpbiBhbWVyaWNhIGltKgIIADIFEAAYgAQyBRAAGIAEMgUQABiABDIFEAAYgAQyBRAAGIAEMgUQABiABDIFEAAYgAQyBRAAGIAEMgUQABiABDIFEAAYgARI6B9Q_A5Y7xJwAXgAkAEAmAGuAaAB9gOqAQMwLjO4AQPIAQD4AQGYAgSgAo4EwgINEAAYgAQYsQMYQxiKBcICBhAAGAcYHsICCBAAGIAEGLEDwgIKEAAYgAQYQxiKBcICCxAAGIAEGLEDGIMBmAMAiAYBkgcDMS4zoAexEbIHAzAuM7gHhATCBwUwLjEuM8gHD4AIAA&sclient=gws-wiz-img")

# %%
print(response)
# Out:
# <Response [200]>

# %%
Soup= BeautifulSoup(response.content,'html.parser')

# %%
Soup
# Out:
# <!DOCTYPE html PUBLIC "-//WAPFORUM//DTD XHTML Mobile 1.0//EN" "http://www.wapforum.org/DTD/xhtml-mobile10.dtd">
# ...

# %%
images_tags = Soup.find_all('img')

# %%
len(images_tags)
# Out:
# 21

# %%
del images_tags[0]

# %%
img_data_mongo = []

for i in images_tags:
    image_url = i['src']
    image_data = requests.get(image_url).content
    mydict = {"index": image_url ,  "image": image_data}
    img_data_mongo.append(mydict) 

    with open(os.path.join(save_dir,f"{query}_{images_tags.index(i)}.jpg"),"wb") as f:
        f.write(image_data)
